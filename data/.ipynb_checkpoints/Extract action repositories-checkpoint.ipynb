# %% [markdown]
# See `README` file for more information about the process performed by this notebook.

# %%
import pandas as pd
import requests
from tqdm import tqdm 

import subprocess
import shutil
from multiprocessing import Pool
from pathlib import Path
from functools import partial

# %%
# Path to clone repositories
WORKING = Path('/data/ghactions')
WORKERS = 40

# %%
repositories = (
    pd.read_csv('../data-raw/repositories.csv')
    # Exclude around 1200 large repositories, for disk space purposes
    .query('Size <= 500 * 1024')
    [['Name', 'Default Branch']]
    .sort_values('Name')
    .values
    .tolist()
)

# %%
print(f'There are {len(repositories)} repositories.')
# Out:
# There are 67870 repositories.

# %% [markdown]
# Let's define a function that will do most of the job for a given repository and its default branch. Inline comments explain the process.

# %%
def download_workflows(base_path: Path, repo: str, branch: str, skip_existing=False, timeout=None):
    """
    Download the GitHub workflow files for given repository. 
    
    :param base_path: target path for downloading the repository. 
    :param repo: name of the repository on GitHub. 
    :param branch: name of the branch to consider.
    :param timeout: timeout for individual command (in seconds).
    """
    # Create repository folder
    path = base_path / repo.replace('/', '---')
    try:
        path.mkdir(parents=True)
    except FileExistsError:
        if not skip_existing:
            raise
       
    # Check if given repository has a .github/workflow folder
    url = f'https://github.com/{repo}/tree/{branch}/.github/workflows'
    r = requests.head(url)
    if r.status_code == 404:
        # Remove folder
        shutil.rmtree(path)
        return
    
    # Quick helper
    cmd = partial(subprocess.run, cwd=path, capture_output=True, timeout=timeout)
    
    # Initialize git repository
    out = cmd(['git', 'init'])
    
    # Configure git repository
    out = cmd(['git', 'remote', 'add', 'origin', 'https://github.com/' + repo])
    out = cmd(['git', 'config', 'core.sparsecheckout', 'true'])
    (path / '.git/info/sparse-checkout').write_text('.github/workflows\n')
    
    # Pull default branch
    try:
        out = cmd(['git', 'pull', 'origin', branch])
        out.check_returncode()
    except (subprocess.CalledProcessError, subprocess.TimeoutExpired):
        # Remove folder
        shutil.rmtree(path)
        raise

# %% [markdown]
# Let's define a thin wrapper to handle errors.

# %%
def job(repository):
    repo, branch = repository
    try:
        download_workflows(WORKING, repo, branch, skip_existing=True, timeout=None)
        return repo, branch
    except Exception as e: 
        return repo, branch, e

# %%
output = []
inputs = repositories[]

with Pool(processes=WORKERS) as pool:
    jobs = pool.imap_unordered(job, inputs)
    for r in tqdm(jobs, total=len(inputs)):
        output.append(r)
# Out:
#   0%|                                     | 126/37870 [00:09<1:17:33,  8.11it/s]

# %%
failures = [x for x in output if len(x) == 3]
print(f'There are {len(failures)} failing repositories out of {len(output)}.')
print('\n'.join(map(str, failures)))
# Out:
# There are 170 failing repositories out of 37870.
# ('jwilder/docker-gen', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('keplergo/lightkurve', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kharchenkolab/conos', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kimmobrunfeldt/chokidar-cli', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kimmobrunfeldt/concurrently', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kode54/cog', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('krakenjs/beaver-logger', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('krakenjs/cross-domain-utils', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('krakenjs/jsx-pragmatic', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('krakenjs/post-robot', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kubeapps/kubeapps', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('leafac/kill-the-newsletter.com', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lepture/flask-wtf', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lessthanoptimal/boofandroiddemo', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lezer-parser/lezer', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lgeiger/node-abi', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lhark/truckersmp-cli', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('liamg/aminal', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('libretime/libretime', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('linkeddata/rdflib.js', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lizheming/waline', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lnbits/lnbits', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lourenci/react-kanban', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('luvsound/pippi', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lyft/kronos', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('m0nica/react-ladies', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('madfish-solutions/templewallet-extension', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('maicoobox/surge', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('matryer/bitbar', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mattrobenolt/jinja2-cli', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mayokunthefirst/instant-weather', 'dev', CalledProcessError(1, ['git', 'pull', 'origin', 'dev'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante dev\n'))
# ('microsoft/vscode-chrome-debug-core', 'main', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('microsoft/vscode-cpptools', 'main', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('microsoft/vscode-debugadapter-node', 'main', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('midwayjs/hooks', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mirumee/saleor', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mirumee/saleor-storefront', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mirumee/saleor-dashboard', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('morgan-stanley/hobbes', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('motemen/gore', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mrooney/mintapi', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mswjs/node-request-interceptor', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mvfsillva/dialetus-service', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mxmzdlv/pybigquery', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nats-io/prometheus-nats-exporter', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nirma/uidevicecomplete', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nirma/uifontcomplete', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nmigen/nmigen', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nuxt-contrib/webpackbar', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nvuillam/mega-linter', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('octokit/auth.js', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('openset/leetcode', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('owasp/benchmark', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pandas-dev/pandas', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pavoni/pywemo', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('peopledoc/procrastinate', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pgrouting/pgrouting', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pi4j/pi4j', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pigigaldi/pock', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pipxproject/pipx', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('plgd-dev/cloud', 'v2', CalledProcessError(1, ['git', 'pull', 'origin', 'v2'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante v2\n'))
# ('pmeier/pystiche', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('polymer/lit-html', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('probot/dco', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('project-slippi/slippi-desktop-app', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('prologic/bitcask', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('prometheus/client_golang', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('protonmail/webclient', 'public', CalledProcessError(1, ['git', 'pull', 'origin', 'public'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante public\n'))
# ('pydata/pandas-gbq', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pymc-devs/aesara', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pyslurm/pyslurm', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('python/cpython', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('python3webspider/deeplearningslidecaptcha', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pythonistaguild/wavelink', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pyutils/line_profiler', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('randombenj/docat', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('react-native-kit/react-native-track-player', 'dev', CalledProcessError(1, ['git', 'pull', 'origin', 'dev'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante dev\n'))
# ('reactivemarkets/react-financial-charts', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('reacttraining/history', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('reacttraining/react-router', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('rechsteiner/parchment', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('replicatedhq/ship', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('ripple/ripple-lib', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('riscv/homebrew-riscv', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('robertoprevato/blacksheep', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('rpi-distro/firmware-nonfree', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('rullzer/previewgenerator', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('russellgoldenberg/scrollama', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('rustpython/rustpython', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('saturday06/vrm_importer_for_blender', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('scaffold-eth/eth-hooks', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('scarface-4711/denonavr', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('scipy/scipy', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('sdl/odata', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('shopify/cli-ui', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('snaptortoise/konami-js', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('snuf/iomemory-vsl', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('soapbox/linkifyjs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('socrata/soda-ruby', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('solegalli/feature_engine', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('spatie/laravel-url-signer', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('speee/jsx-slack', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('spotter-application/spotter', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('springhgui/fasttunnel', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('square/assistedinject', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('square/inflationinject', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('stackworx/formik-material-ui', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('stevenosloan/slack-notifier', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('supabase/pg-api', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('swanson/stringer', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('swc-project/swc', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('taketo1024/swiftymath', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('takluyver/flit', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tankerhq/tsrc', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tannerlinsley/react-table', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tbroyer/gwt-maven-archetypes', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tc39-transfer/proposal-regex-escaping', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('terra-project/core', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('terraform-providers/terraform-provider-azurerm', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('thecodingmachine/gotenberg', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('thekevinscott/upscalerjs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tinche/cattrs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('transmission/transmission', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tswast/pybigquery', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('turtlep/lovepotion', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('typo3/typo3.cms', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('ultz/silk.net', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('umbopepato/velociraptor', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('unboundev/node-strava-v3', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('understrap/understrap-child', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('uniswap/uniswap-org', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('uniswap/uniswap-sdk', 'v2', CalledProcessError(1, ['git', 'pull', 'origin', 'v2'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante v2\n'))
# ('unity-technologies/alembicforunity', 'dev', CalledProcessError(1, ['git', 'pull', 'origin', 'dev'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante dev\n'))
# ('unity-technologies/com.unity.multiplayer.mlapi', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('usthe/sureness', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('varabeis/awesome-ios-ui', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('varabeis/spalert', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('varabeis/sppermissions', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vazkii/botania', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vazkii/patchouli', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vazkiismods/botania', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vgropp/bwm-ng', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vivien8261/amiya-bot', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vlang/vls', 'use-tree-sitter', CalledProcessError(1, ['git', 'pull', 'origin', 'use-tree-sitter'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante use-tree-sitter\n'))
# ('volantmq/volantmq', 'master', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('volcano-sh/volcano', 'master', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('volumio/volumio2', 'master', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('vonovak/react-navigation-header-buttons', 'master', ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))))
# ('vuejs/vue-devtools', 'next', CalledProcessError(1, ['git', 'pull', 'origin', 'next'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante next\n'))
# ('vuejs/vue-router-next', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vuejs/vue-next', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vuejs/vue-test-utils-next', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vvo/next-iron-session', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vvo/selenium-standalone', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('windows-toolkit/lottie-windows', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wluper/lida', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wmde/fundraisingfrontend', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('woowacourse/javable', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wp-cli/handbook', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('writeup007/weibo_hot_search', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('xamarin/mobileblazorbindings', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('xamarin/torchsharp', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('ydj-fe/ts-react-webpack', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('yisar/snel', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('yonsm/haextra', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('yuanchuan/node-watch', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('yurunsoft/imi', 'dev', CalledProcessError(1, ['git', 'pull', 'origin', 'dev'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante dev\n'))
# ('zamiell/hanabi-live', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('ziulev/spotter', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('zoeyg/binance', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
